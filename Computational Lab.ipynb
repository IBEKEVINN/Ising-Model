# %% [markdown]
# # Computational Lab (Ising Model)
# ## Kevin Nguyen (z5117568)

# %% [markdown]
# - To calculate spin alignment behaviour and calculate the temp of phase transition between magnetic and chaotic in a regulat lattice
# - S for individual electron spin, L for resultant orbital momentum
# - If some subsheklls are partially filled, L and/or S are nonzero\
# - At a critical temp, Tc, lattice no longer maintians ordered behaviour. Undergoes phase transition.

# %%
import Ising_model as model

# %%
exp1 = model.plots(N=15,start='High',inc=0.03)
exp1.E()
exp1.show()
# Out:
# No handles with labels found to put in legend.

# %%
exp1.mag()
exp1.show()
# Out:
# No handles with labels found to put in legend.

# %%
exp1.mag_sus()
exp1.show()
# Out:
# No handles with labels found to put in legend.

# %%
exp1.lattice()
exp1.show()
# Red/Blue for Up/Down
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# #### **Experiment 1**
# Magnetization versus temperature for a small lattice

# %%
exp1 = model.plots(N=30, start='Low')
exp1.mag()
exp1.show()
# Out:
# No handles with labels found to put in legend.

# %%
exp1 = model.plots(N=30, start='High')
exp1.mag()
exp1.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# #### **Experiment 2**
# Magnetic Susceptibility versus temperature for a larger lattice

# %%
exp2 = model.plots(N=30,start='Low')
exp2.mag_sus()
exp2.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# #### **Experiment 3**
# Map out the spin distribution at fixed temperatures

# %%
exp3 = model.plots(N=100, T=1.5)
exp3.lattice()
exp3.show()
# Out:
# No handles with labels found to put in legend.

# %%
exp3 = model.plots(N=100, T=2)
exp3.lattice()
exp3.show()
# Out:
# No handles with labels found to put in legend.

# %%
exp3 = model.plots(N=100, T=3.5)
exp3.lattice()
exp3.show()
# Out:
# No handles with labels found to put in legend.

# %%
exp3 = model.plots(N=100, T=4)
exp3.lattice()
exp3.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# #### **Experiment 4**
# Including an external magnetic field

# %% [markdown]
# **Question 1: Describe what is happening physically as you increase T in the 'cold' start lattice in
# experiment 1, and how your plot of magnetization versus temperature reflects that physical change.
# Describe the differences between the magnetization versus temperature plots for the 'cold' start and
# the 'hot' start. What in the program might be causing those differences?**

# %% [markdown]
# **Question 2: Based on your data from experiments 1 and 2, what is the value of Tc? How certain are
# you? Which measured quantity is most informative for answering this question? Describe two ways
# you could improve the accuracy of your measurement.**

# %% [markdown]
# **Question 3: Describe how the spin distribution maps in experiment 3 change with rising temperature.
# How does the behaviour you see in the maps correspond to physical properties like magnetization
# and susceptibility?**

# %% [markdown]
# **Question 4: What changes in your Ising model when you apply an external magnetic field? How can
# this be seen in your figures and your spin distribution maps?**
